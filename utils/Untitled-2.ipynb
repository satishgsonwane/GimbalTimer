# %%
import pandas as pd

# %%
data = pd.read_csv('/home/ozsports/Documents/WIP/GimbalTimer/data.csv')

# %%
data.head()
# Out:
#    cam_id  gimbal_speed  pan_setpoint  tilt_setpoint  execution_time
# 0       2             2           -50              0            1.59
# 1       2             2           -45              0            1.59
# 2       2             2           -50              0            2.20
# 3       2             2           -40              0            1.59
# 4       2             2           -50              0            2.40

# %%
# get execution time for even and odd rows
execution_time_even = data['execution_time'][data.index % 2 == 0]
execution_time_odd =  data['execution_time'][data.index % 2 != 0]

# %%
# plot execution time
execution_time_even.plot()
# Out:
# <Axes: >

# %%
execution_time_odd.plot()
# Out:
# <Axes: >

# %%
print (execution_time_odd)
# Out:
# 1     1.59
# 3     1.59
# 5     1.80
# 7     1.40
# 9     1.99
# 11    1.80
# 13    1.59
# 15    1.80
# 17    1.80
# 19    2.00
# 21    2.19
# 23    2.21
# 25    2.40
# 27    2.80
# 29    3.40
# 31    3.20
# 33    3.20
# 35    3.40
# 37    3.99
# 39    3.40
# Name: execution_time, dtype: float64
